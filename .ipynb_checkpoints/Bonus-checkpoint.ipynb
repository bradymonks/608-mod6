# %%
## Bonus

# %%
import pandas as pd

# %%
sports = pd.read_csv('AllSports.csv')
# Out:
# C:\Users\brady\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
sports.head()
## Brady Monks
# Out:
#    Unnamed: 0      FullName Location                       College  \
# 0        7552  Dick Stovall      NaN  Abilene Christian University
# 1        7553  Mark Jackson      NaN  Abilene Christian University
# 2        7554     Larry Cox      NaN  Abilene Christian University
# 3        7555  Grant Feasel      NaN  Abilene Christian University
# 4        7556   Greg Feasel      NaN  Abilene Christian University
#
#    CollegeYear    BirthDay  DeathDate    BirthPlace BirthCity BirthState  \
# 0       1941.0    5/4/1922   6/4/1999    Albany, TX    Albany         TX
# 1       1981.0   3/16/1962        NaN  Amarillo, TX  Amarillo         TX
# 2       1962.0  11/12/1943        NaN     Anson, TX     Anson         TX
# 3       1979.0   6/28/1960  7/15/2012   Barstow, CA   Barstow         CA
# 4       1976.0   11/7/1957        NaN   Barstow, CA   Barstow         CA
#
#   Weight  Height Handedness   HighSchool        DraftTeam DraftPick  \
# ...

# %%
sports=sports.rename(columns = {'Unnamed: 0':'ID'})

# %%
sports.head()
# Out:
#      ID      FullName Location                       College  CollegeYear  \
# 0  7552  Dick Stovall      NaN  Abilene Christian University       1941.0
# 1  7553  Mark Jackson      NaN  Abilene Christian University       1981.0
# 2  7554     Larry Cox      NaN  Abilene Christian University       1962.0
# 3  7555  Grant Feasel      NaN  Abilene Christian University       1979.0
# 4  7556   Greg Feasel      NaN  Abilene Christian University       1976.0
#
#      BirthDay  DeathDate    BirthPlace BirthCity BirthState Weight  Height  \
# 0    5/4/1922   6/4/1999    Albany, TX    Albany         TX    202  Jun-00
# 1   3/16/1962        NaN  Amarillo, TX  Amarillo         TX    180   9-May
# 2  11/12/1943        NaN     Anson, TX     Anson         TX    255   3-Jun
# 3   6/28/1960  7/15/2012   Barstow, CA   Barstow         CA    278   7-Jun
# 4   11/7/1957        NaN   Barstow, CA   Barstow         CA    300   7-Jun
#
# ...

# %%
sports.describe()
# Out:
#                  ID   CollegeYear
# count  37278.000000  36116.000000  0.0
# mean   18639.500000   1975.652647  NaN
# std    10761.376004     26.911480  NaN
# min        1.000000   1864.000000  NaN
# 25%     9320.250000   1961.000000  NaN
# 50%    18639.500000   1981.000000  NaN
# 75%    27958.750000   1997.000000  NaN
# max    37278.000000   2018.000000  NaN

# %%
# %matplotlib
## Brady Monks
# Out:
# Using matplotlib backend: Qt5Agg

# %%
histogram = sports.hist()
